# %%
import pandas as pd
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('./iris.csv', header=None)
data.head()
# Out:
#      0    1    2    3            4
# 0  5.1  3.5  1.4  0.2  Iris-setosa
# 1  4.9  3.0  1.4  0.2  Iris-setosa
# 2  4.7  3.2  1.3  0.2  Iris-setosa
# 3  4.6  3.1  1.5  0.2  Iris-setosa
# 4  5.0  3.6  1.4  0.2  Iris-setosa

# %%
y = data[4]
X = data.drop(4, axis=1)

# %%
X.head()
# Out:
#      0    1    2    3
# 0  5.1  3.5  1.4  0.2
# 1  4.9  3.0  1.4  0.2
# 2  4.7  3.2  1.3  0.2
# 3  4.6  3.1  1.5  0.2
# 4  5.0  3.6  1.4  0.2

# %%
encoder = LabelEncoder()
encoder.fit(y)
encoded_y = encoder.transform(y)
dummy_y = to_categorical(encoded_y)

# %%
#init model
first_model = Sequential()
#add layers
#fully connected layers
first_model.add(Dense(4, activation='relu', name='fc1', input_shape=(4,)))
first_model.add(Dense(3, activation='softmax', name='fc2'))
#compile model with optimizer, loss function and metrics
first_model.compile(optimizer='adam',loss='categorical_crossentropy', metrics=['accuracy'])
#describe NN
first_model.summary()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  fc1 (Dense)                 (None, 4)                 20
#
#  fc2 (Dense)                 (None, 3)                 15
#
# ...
# Total params: 35 (140.00 Byte)
# Trainable params: 35 (140.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
second_model = Sequential()
second_model.add(Dense(16, activation='sigmoid', name='fc1', input_shape=(4,)))
second_model.add(Dense(3, activation='softmax', name='fc2'))
second_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
second_model.summary()
# Out:
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  fc1 (Dense)                 (None, 16)                80
#
#  fc2 (Dense)                 (None, 3)                 51
#
# ...
# Total params: 131 (524.00 Byte)
# Trainable params: 131 (524.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
third_model = Sequential()
third_model.add(Dense(16, activation='sigmoid', name='fc1', input_shape=(4,)))
third_model.add(Dense(3, activation='softmax', name='fc2'))
third_model.compile(optimizer='sgd', loss='categorical_crossentropy', metrics=['accuracy'])
third_model.summary()
# Out:
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  fc1 (Dense)                 (None, 16)                80
#
#  fc2 (Dense)                 (None, 3)                 51
#
# ...
# Total params: 131 (524.00 Byte)
# Trainable params: 131 (524.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
history1_1 = first_model.fit(X, dummy_y, epochs=25, batch_size=10, validation_split=0.1)
# Out:
# Epoch 1/25
# 14/14 [==============================] - 0s 10ms/step - loss: 5.5662 - accuracy: 0.3704 - val_loss: 7.5282 - val_accuracy: 0.0000e+00
# Epoch 2/25
# 14/14 [==============================] - 0s 2ms/step - loss: 4.8227 - accuracy: 0.3704 - val_loss: 6.2713 - val_accuracy: 0.0000e+00
# Epoch 3/25
# 14/14 [==============================] - 0s 2ms/step - loss: 4.0555 - accuracy: 0.3704 - val_loss: 5.0243 - val_accuracy: 0.0000e+00
# Epoch 4/25
# 14/14 [==============================] - 0s 2ms/step - loss: 3.2969 - accuracy: 0.3704 - val_loss: 3.7780 - val_accuracy: 0.0000e+00
# Epoch 5/25
# 14/14 [==============================] - 0s 2ms/step - loss: 2.5625 - accuracy: 0.3704 - val_loss: 2.5730 - val_accuracy: 0.0000e+00
# Epoch 6/25
# 14/14 [==============================] - 0s 2ms/step - loss: 1.8812 - accuracy: 0.3704 - val_loss: 1.6363 - val_accuracy: 0.0000e+00
# Epoch 7/25
# ...

# %%
history1_2 = first_model.fit(X, dummy_y, epochs=100, batch_size=5, validation_split=0.1)
# Out:
# Epoch 1/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6958 - accuracy: 0.4667 - val_loss: 1.2506 - val_accuracy: 0.0000e+00
# Epoch 2/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6891 - accuracy: 0.4667 - val_loss: 1.1856 - val_accuracy: 0.0000e+00
# Epoch 3/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6823 - accuracy: 0.4519 - val_loss: 1.2549 - val_accuracy: 0.0000e+00
# Epoch 4/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6716 - accuracy: 0.5185 - val_loss: 1.2162 - val_accuracy: 0.0000e+00
# Epoch 5/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6643 - accuracy: 0.5111 - val_loss: 1.2004 - val_accuracy: 0.0000e+00
# Epoch 6/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6577 - accuracy: 0.4593 - val_loss: 1.1195 - val_accuracy: 0.0000e+00
# Epoch 7/100
# ...

# %%
history2_1 = second_model.fit(X, dummy_y, epochs=25, batch_size=10, validation_split=0.1)
# Out:
# Epoch 1/25
# 14/14 [==============================] - 0s 9ms/step - loss: 1.2115 - accuracy: 0.3852 - val_loss: 0.9527 - val_accuracy: 0.0000e+00
# Epoch 2/25
# 14/14 [==============================] - 0s 2ms/step - loss: 1.1369 - accuracy: 0.3926 - val_loss: 0.9909 - val_accuracy: 0.0000e+00
# Epoch 3/25
# 14/14 [==============================] - 0s 2ms/step - loss: 1.0889 - accuracy: 0.4667 - val_loss: 0.9942 - val_accuracy: 0.5333
# Epoch 4/25
# 14/14 [==============================] - 0s 2ms/step - loss: 1.0480 - accuracy: 0.4889 - val_loss: 1.0558 - val_accuracy: 0.2667
# Epoch 5/25
# 14/14 [==============================] - 0s 2ms/step - loss: 1.0150 - accuracy: 0.4593 - val_loss: 1.0668 - val_accuracy: 0.2000
# Epoch 6/25
# 14/14 [==============================] - 0s 2ms/step - loss: 0.9939 - accuracy: 0.5037 - val_loss: 1.0671 - val_accuracy: 0.4667
# Epoch 7/25
# ...

# %%
history2_2 = second_model.fit(X, dummy_y, epochs=100, batch_size=5, validation_split=0.1)
# Out:
# Epoch 1/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6562 - accuracy: 0.7852 - val_loss: 0.8924 - val_accuracy: 0.0000e+00
# Epoch 2/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6358 - accuracy: 0.7704 - val_loss: 0.9030 - val_accuracy: 0.0000e+00
# Epoch 3/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6187 - accuracy: 0.8593 - val_loss: 0.8146 - val_accuracy: 0.6000
# Epoch 4/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5983 - accuracy: 0.8370 - val_loss: 0.8659 - val_accuracy: 0.0000e+00
# Epoch 5/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5812 - accuracy: 0.7852 - val_loss: 0.8476 - val_accuracy: 0.2000
# Epoch 6/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5657 - accuracy: 0.8222 - val_loss: 0.8127 - val_accuracy: 0.4000
# Epoch 7/100
# ...

# %%
history3_1 = third_model.fit(X, dummy_y, epochs=25, batch_size=10, validation_split=0.1)
# Out:
# Epoch 1/25
# 14/14 [==============================] - 0s 10ms/step - loss: 1.4683 - accuracy: 0.3704 - val_loss: 1.6476 - val_accuracy: 0.0000e+00
# Epoch 2/25
# 14/14 [==============================] - 0s 2ms/step - loss: 1.2141 - accuracy: 0.3704 - val_loss: 1.4090 - val_accuracy: 0.0000e+00
# Epoch 3/25
# 14/14 [==============================] - 0s 2ms/step - loss: 1.0919 - accuracy: 0.3704 - val_loss: 1.3191 - val_accuracy: 0.0000e+00
# Epoch 4/25
# 14/14 [==============================] - 0s 2ms/step - loss: 1.0336 - accuracy: 0.3704 - val_loss: 1.2854 - val_accuracy: 0.0000e+00
# Epoch 5/25
# 14/14 [==============================] - 0s 2ms/step - loss: 0.9993 - accuracy: 0.3704 - val_loss: 1.2394 - val_accuracy: 0.0000e+00
# Epoch 6/25
# 14/14 [==============================] - 0s 2ms/step - loss: 0.9762 - accuracy: 0.3852 - val_loss: 1.2318 - val_accuracy: 0.0000e+00
# Epoch 7/25
# ...

# %%
history3_2 = third_model.fit(X, dummy_y, epochs=100, batch_size=5, validation_split=0.1)
# Out:
# Epoch 1/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.7559 - accuracy: 0.7407 - val_loss: 1.0531 - val_accuracy: 0.0000e+00
# Epoch 2/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.7403 - accuracy: 0.7333 - val_loss: 1.0229 - val_accuracy: 0.0000e+00
# Epoch 3/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.7254 - accuracy: 0.7407 - val_loss: 1.0059 - val_accuracy: 0.0000e+00
# Epoch 4/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.7131 - accuracy: 0.7407 - val_loss: 0.9889 - val_accuracy: 0.0000e+00
# Epoch 5/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6989 - accuracy: 0.7333 - val_loss: 0.9599 - val_accuracy: 0.0000e+00
# Epoch 6/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6855 - accuracy: 0.7481 - val_loss: 0.9748 - val_accuracy: 0.0000e+00
# Epoch 7/100
# ...

# %%
hist = history1_1.history
fig = plt.figure(figsize=(12, 5))
ax = fig.add_subplot(1, 2, 1)
ax.plot(hist['loss'], lw=3)
ax.set_title('Training loss', size=15)
ax.set_xlabel('Epoch', size=15)
ax.tick_params(axis='both', which='major', labelsize=15)

ax = fig.add_subplot(1, 2, 2)
ax.plot(hist['accuracy'], lw=3)
ax.set_title('Training accuracy', size=15)
ax.set_xlabel('Epoch', size=15)
ax.tick_params(axis='both', which='major', labelsize=15)
plt.tight_layout()
#plt.savefig('ch13-cls-learning-curve.pdf')

plt.show()

# %%
hist = history1_2.history
fig = plt.figure(figsize=(12, 5))
ax = fig.add_subplot(1, 2, 1)
ax.plot(hist['loss'], lw=3)
ax.set_title('Training loss', size=15)
ax.set_xlabel('Epoch', size=15)
ax.tick_params(axis='both', which='major', labelsize=15)

ax = fig.add_subplot(1, 2, 2)
ax.plot(hist['accuracy'], lw=3)
ax.set_title('Training accuracy', size=15)
ax.set_xlabel('Epoch', size=15)
ax.tick_params(axis='both', which='major', labelsize=15)
plt.tight_layout()
#plt.savefig('ch13-cls-learning-curve.pdf')

plt.show()

# %%
hist = history2_1.history
fig = plt.figure(figsize=(12, 5))
ax = fig.add_subplot(1, 2, 1)
ax.plot(hist['loss'], lw=3)
ax.set_title('Training loss', size=15)
ax.set_xlabel('Epoch', size=15)
ax.tick_params(axis='both', which='major', labelsize=15)

ax = fig.add_subplot(1, 2, 2)
ax.plot(hist['accuracy'], lw=3)
ax.set_title('Training accuracy', size=15)
ax.set_xlabel('Epoch', size=15)
ax.tick_params(axis='both', which='major', labelsize=15)
plt.tight_layout()
#plt.savefig('ch13-cls-learning-curve.pdf')

plt.show()

# %%
hist = history2_2.history
fig = plt.figure(figsize=(12, 5))
ax = fig.add_subplot(1, 2, 1)
ax.plot(hist['loss'], lw=3)
ax.set_title('Training loss', size=15)
ax.set_xlabel('Epoch', size=15)
ax.tick_params(axis='both', which='major', labelsize=15)

ax = fig.add_subplot(1, 2, 2)
ax.plot(hist['accuracy'], lw=3)
ax.set_title('Training accuracy', size=15)
ax.set_xlabel('Epoch', size=15)
ax.tick_params(axis='both', which='major', labelsize=15)
plt.tight_layout()
#plt.savefig('ch13-cls-learning-curve.pdf')

plt.show()

# %%
hist = history3_1.history
fig = plt.figure(figsize=(12, 5))
ax = fig.add_subplot(1, 2, 1)
ax.plot(hist['loss'], lw=3)
ax.set_title('Training loss', size=15)
ax.set_xlabel('Epoch', size=15)
ax.tick_params(axis='both', which='major', labelsize=15)

ax = fig.add_subplot(1, 2, 2)
ax.plot(hist['accuracy'], lw=3)
ax.set_title('Training accuracy', size=15)
ax.set_xlabel('Epoch', size=15)
ax.tick_params(axis='both', which='major', labelsize=15)
plt.tight_layout()
#plt.savefig('ch13-cls-learning-curve.pdf')

plt.show()

# %%
hist = history3_2.history
fig = plt.figure(figsize=(12, 5))
ax = fig.add_subplot(1, 2, 1)
ax.plot(hist['loss'], lw=3)
ax.set_title('Training loss', size=15)
ax.set_xlabel('Epoch', size=15)
ax.tick_params(axis='both', which='major', labelsize=15)

ax = fig.add_subplot(1, 2, 2)
ax.plot(hist['accuracy'], lw=3)
ax.set_title('Training accuracy', size=15)
ax.set_xlabel('Epoch', size=15)
ax.tick_params(axis='both', which='major', labelsize=15)
plt.tight_layout()
#plt.savefig('ch13-cls-learning-curve.pdf')

plt.show()
